# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")

slice = [59210, 55466, 47544, 36443, 35917]
labels = ['Javascript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.5, 0]

plt.pie(slice, labels=labels, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})

plt.title("My Awesome Pie Chart")
plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
labels = ['CDIA','CONT','AUTO', 'INFO']
color = ['#008fd5', '#fc4f30', '#e5ae37', '#69904f']
slices =[120, 80, 30, 20]
plt.pie(slices, labels = labels, wedgeprops={'edgecolor':'#c0c0c0'})

plt.title('Mi Gráfico de pastel')
plt.tight_layout()
plt.show()

#colores
#Blue = #008fd5
#Red = #fc4f30
#yellow = #e5ae37
#Green = #69904f

colors = ['#008fd5', '#fc4f30', '#e5ae37', '#69904f']
